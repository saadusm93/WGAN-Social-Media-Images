# %% [markdown]
# #### Run 2
# #### 1) Added minibatchstd to force Generator to produce variety.
# #### 2) Reduced gradient penalty from 10 to 8
# #### 3) Reducing G lr by 40% at epoch 199

# %%
import os
import random
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.utils import save_image
from torch.nn.utils import spectral_norm

#Variables
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
data_path = r'E:\Projects\Data\VW-GAN\Images\128'  
save_path = r'E:\Projects\Data\VW-GAN\Images\Generated'   
os.makedirs(save_path, exist_ok=True)

epochs = 500
batch_size = 64
lr_g = 0.0001
lr_d = 0.0002
latent_dim = 128
img_size = 128
channels = 3
critic_iter = 5   # number of D updates per G update
lambda_gp = 8    # gradient penalty weight

# Add transformations for variety
# Convert to tensors and normalize
transform = transforms.Compose([transforms.RandomHorizontalFlip(p = 0.5),transforms.RandomRotation((-5,5)),transforms.ToTensor(),transforms.Normalize([0.5], [0.5])])

dataset = datasets.ImageFolder(root=data_path, transform=transform)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=4, pin_memory=True)


#GENERATOR CLASS
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.init_size = img_size // 32  
        self.fc = nn.Linear(latent_dim, 512 * self.init_size * self.init_size)

        self.conv_blocks = nn.Sequential(
            nn.BatchNorm2d(512),

            nn.Upsample(scale_factor=2),  # 4x4 to 8x8
            nn.Conv2d(512, 256, 3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),

            nn.Upsample(scale_factor=2),  # 8x8 to 16x16
            nn.Conv2d(256, 128, 3, stride=1, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Upsample(scale_factor=2),  # 16x16 to 32x32
            nn.Conv2d(128, 64, 3, stride=1, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Upsample(scale_factor=2),  # 32x32 to 64x64
            nn.Conv2d(64, 32, 3, stride=1, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),

            nn.Upsample(scale_factor=2),  # 64x64 to 128x128
            nn.Conv2d(32, channels, 3, stride=1, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        out = self.fc(z)
        out = out.view(out.shape[0], 512, self.init_size, self.init_size)  # Should be [batch, 512, 4, 4]
        img = self.conv_blocks(out)
        return img
        

# MINIBATCH CLASS
class Minibatch(nn.Module):
    def __init__(self):
        super(Minibatch, self).__init__()

    def forward(self,x):
        batch_std = torch.std(x, dim = 0, keepdim = True)
        mean_std = batch_std.mean().view(1,1,1,1)
        shape = list(x.shape)
        shape[1] = 1
        std_map = mean_std.expand(shape)
        return torch.cat([x, std_map],1)


#DISCRIMINATOR CLASS
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        def block(in_channels, out_channels, normalize=True):
            layers = [nn.utils.spectral_norm(nn.Conv2d(in_channels, out_channels, 4, 2, 1))]
            if normalize:
                layers.append(nn.InstanceNorm2d(out_channels))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *block(channels, 32, normalize=False),  # 128 to 64
            *block(32, 64),                         # 64 to 32
            *block(64, 128),                        # 32 to 16
            *block(128, 256),                       # 16to 8
            *block(256, 512),                       # 8 to 4
            Minibatch(),
        )

        self.adv_layer = nn.utils.spectral_norm(nn.Linear(513 * 4 * 4, 1))

    def forward(self, img):
        out = self.model(img)
        out = out.view(out.shape[0], -1)
        validity = self.adv_layer(out)
        return validity


#Initial weights
def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1 or classname.find('Linear') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        if hasattr(m, 'bias') and m.bias is not None:
            nn.init.constant_(m.bias.data, 0)


#Gradient penalty
def compute_gradient_penalty(D, real_samples, fake_samples):
    alpha = torch.rand(real_samples.size(0), 1, 1, 1, device=device)
    interpolates = (alpha * real_samples + (1 - alpha) * fake_samples).requires_grad_(True)
    d_interpolates = D(interpolates)
    fake = torch.ones(d_interpolates.size(), device=device, requires_grad=False)
    gradients = torch.autograd.grad(
        outputs=d_interpolates,
        inputs=interpolates,
        grad_outputs=fake,
        create_graph=True,
        retain_graph=True,
        only_inputs=True
    )[0]
    gradients = gradients.view(gradients.size(0), -1)
    gradient_penalty = ((gradients.norm(2, dim=1) - 1) ** 2).mean()
    return gradient_penalty


# Models
generator = Generator().to(device)
discriminator = Discriminator().to(device)
generator.apply(weights_init_normal)
discriminator.apply(weights_init_normal)

optimizer_G = torch.optim.Adam(generator.parameters(), lr=lr_g, betas=(0.0, 0.9))
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=lr_d, betas=(0.0, 0.9))


#Training loop
print("Starting training")

for epoch in range(epochs):
    
    for i, (imgs, _) in enumerate(dataloader):

        real_imgs = imgs.to(device)

        # Train D
        for _ in range(critic_iter):
            z = torch.randn(imgs.size(0), latent_dim, device=device)
            fake_imgs = generator(z).detach()
            real_validity = discriminator(real_imgs)
            fake_validity = discriminator(fake_imgs)
            gp = compute_gradient_penalty(discriminator, real_imgs.data, fake_imgs.data)
            d_loss = -torch.mean(real_validity) + torch.mean(fake_validity) + lambda_gp * gp

            optimizer_D.zero_grad()
            d_loss.backward()
            optimizer_D.step()

        # Train G
        z = torch.randn(imgs.size(0), latent_dim, device=device)
        gen_imgs = generator(z)
        g_loss = -torch.mean(discriminator(gen_imgs))

        optimizer_G.zero_grad()
        g_loss.backward()
        optimizer_G.step()

        if i % 100 == 0:
            print(f"[Epoch {epoch}/{epochs}] [Batch {i}/{len(dataloader)}] [D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]")

    # Save generated images
    if epoch % 5 == 0:
        save_image(gen_imgs.data[:25], f"{save_path}/{epoch:03d}.png", nrow=8, normalize=True)

    # Save model checkpoints
    if epoch % 20 == 0:
        torch.save(generator.state_dict(), f"{save_path}/generator_epoch_{epoch}.pth")
        torch.save(discriminator.state_dict(), f"{save_path}/discriminator_epoch_{epoch}.pth")

    # Lower G's learning rate by 20%
    if epoch == 100:
        for param_group in optimizer_G.param_groups:
            param_group['lr'] *= 0.8   
        print(f"Lowered Generator learning rate to {optimizer_G.param_groups[0]['lr']} at epoch {epoch}!")

    if epoch == 130:
        for param_group in optimizer_G.param_groups:
            param_group['betas'] = (0.2, 0.999)
        print("Generator beta1 updated to 0.2.")


    if epoch == 199:
        for param_group in optimizer_G.param_groups:
            param_group['lr'] = param_group['lr'] * 0.6
        print(f"Lowered Generator learning rate to {optimizer_G.param_groups[0]['lr']} at epoch {epoch}!")
        

print("Training completed.")
# Out:
# Starting training
# E:\conda_envs\vw-gpu\lib\site-packages\torch\autograd\graph.py:825: UserWarning: Attempting to run cuBLAS, but there was no current CUDA context! Attempting to set the primary context... (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\cuda\CublasHandlePool.cpp:135.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# [Epoch 0/500] [Batch 0/26] [D loss: 5.7969] [G loss: 0.1767]
# [Epoch 1/500] [Batch 0/26] [D loss: -25.9275] [G loss: 18.9995]
# [Epoch 2/500] [Batch 0/26] [D loss: -28.3046] [G loss: 17.4357]
# [Epoch 3/500] [Batch 0/26] [D loss: -30.7030] [G loss: 20.8925]
# [Epoch 4/500] [Batch 0/26] [D loss: -39.6313] [G loss: 41.1216]
# [Epoch 5/500] [Batch 0/26] [D loss: -25.5643] [G loss: 30.1762]
# [Epoch 6/500] [Batch 0/26] [D loss: -41.1902] [G loss: 26.7998]
# [Epoch 7/500] [Batch 0/26] [D loss: -31.9361] [G loss: 19.7910]
# [Epoch 8/500] [Batch 0/26] [D loss: -44.3136] [G loss: 21.0074]
# [Epoch 9/500] [Batch 0/26] [D loss: -45.6690] [G loss: 42.0007]
# [Epoch 10/500] [Batch 0/26] [D loss: -46.4741] [G loss: 30.3244]
# [Epoch 11/500] [Batch 0/26] [D loss: -43.5613] [G loss: 37.6718]
# [Epoch 12/500] [Batch 0/26] [D loss: -47.9637] [G loss: 46.5432]
# [Epoch 13/500] [Batch 0/26] [D loss: -48.7406] [G loss: 46.1086]
# [Epoch 14/500] [Batch 0/26] [D loss: -40.0169] [G loss: 28.1698]
# [Epoch 15/500] [Batch 0/26] [D loss: -43.8312] [G loss: 28.7343]
# [Epoch 16/500] [Batch 0/26] [D loss: -46.7416] [G loss: 27.5073]
# [Epoch 17/500] [Batch 0/26] [D loss: -53.5374] [G loss: 44.6361]
# [Epoch 18/500] [Batch 0/26] [D loss: -43.4034] [G loss: 27.1078]
# [Epoch 19/500] [Batch 0/26] [D loss: -47.0802] [G loss: 50.1084]
# [Epoch 20/500] [Batch 0/26] [D loss: -37.0871] [G loss: 41.7297]
# [Epoch 21/500] [Batch 0/26] [D loss: -40.1194] [G loss: 41.4904]
# [Epoch 22/500] [Batch 0/26] [D loss: -48.6752] [G loss: 8.7339]
# [Epoch 23/500] [Batch 0/26] [D loss: -26.4303] [G loss: 47.8154]
# [Epoch 24/500] [Batch 0/26] [D loss: -41.0666] [G loss: 26.5972]
# [Epoch 25/500] [Batch 0/26] [D loss: -41.1345] [G loss: 39.1989]
# [Epoch 26/500] [Batch 0/26] [D loss: -49.9648] [G loss: 26.4923]
# [Epoch 27/500] [Batch 0/26] [D loss: -45.1678] [G loss: 49.1014]
# [Epoch 28/500] [Batch 0/26] [D loss: -40.0182] [G loss: 34.5530]
# [Epoch 29/500] [Batch 0/26] [D loss: -44.3029] [G loss: 14.3939]
# [Epoch 30/500] [Batch 0/26] [D loss: -54.5996] [G loss: 38.6810]
# [Epoch 31/500] [Batch 0/26] [D loss: -38.6224] [G loss: 29.3681]
# [Epoch 32/500] [Batch 0/26] [D loss: -39.7558] [G loss: 22.6322]
# [Epoch 33/500] [Batch 0/26] [D loss: -38.0192] [G loss: 50.0811]
# [Epoch 34/500] [Batch 0/26] [D loss: -47.7778] [G loss: 46.4586]
# [Epoch 35/500] [Batch 0/26] [D loss: -45.0390] [G loss: 43.4198]
# [Epoch 36/500] [Batch 0/26] [D loss: -42.6069] [G loss: 34.0009]
# [Epoch 37/500] [Batch 0/26] [D loss: -46.0172] [G loss: 43.2366]
# [Epoch 38/500] [Batch 0/26] [D loss: -44.3661] [G loss: 34.4145]
# [Epoch 39/500] [Batch 0/26] [D loss: -36.4572] [G loss: 34.1729]
# [Epoch 40/500] [Batch 0/26] [D loss: -27.1451] [G loss: 22.1762]
# [Epoch 41/500] [Batch 0/26] [D loss: -37.1092] [G loss: 39.9555]
# [Epoch 42/500] [Batch 0/26] [D loss: -26.2235] [G loss: 31.4452]
# [Epoch 43/500] [Batch 0/26] [D loss: -44.9247] [G loss: 27.7409]
# [Epoch 44/500] [Batch 0/26] [D loss: -48.0796] [G loss: 38.9058]
# [Epoch 45/500] [Batch 0/26] [D loss: -38.0334] [G loss: 18.5120]
# [Epoch 46/500] [Batch 0/26] [D loss: -23.4521] [G loss: 47.2305]
# [Epoch 47/500] [Batch 0/26] [D loss: -34.5607] [G loss: 49.6108]
# [Epoch 48/500] [Batch 0/26] [D loss: -44.0307] [G loss: 43.7925]
# [Epoch 49/500] [Batch 0/26] [D loss: -45.9794] [G loss: 34.7549]
# [Epoch 50/500] [Batch 0/26] [D loss: -41.5327] [G loss: 26.8178]
# [Epoch 51/500] [Batch 0/26] [D loss: -43.4535] [G loss: 42.4768]
# [Epoch 52/500] [Batch 0/26] [D loss: -41.1160] [G loss: 30.9815]
# [Epoch 53/500] [Batch 0/26] [D loss: -39.9271] [G loss: 44.3498]
# [Epoch 54/500] [Batch 0/26] [D loss: -46.2284] [G loss: 38.9399]
# [Epoch 55/500] [Batch 0/26] [D loss: -28.0468] [G loss: 43.7263]
# [Epoch 56/500] [Batch 0/26] [D loss: -47.1280] [G loss: 35.9909]
# [Epoch 57/500] [Batch 0/26] [D loss: -42.8104] [G loss: 27.4796]
# [Epoch 58/500] [Batch 0/26] [D loss: -47.6764] [G loss: 29.9820]
# [Epoch 59/500] [Batch 0/26] [D loss: -42.6335] [G loss: 37.1168]
# [Epoch 60/500] [Batch 0/26] [D loss: -42.3822] [G loss: 40.7778]
# [Epoch 61/500] [Batch 0/26] [D loss: -32.9271] [G loss: 50.2135]
# [Epoch 62/500] [Batch 0/26] [D loss: -41.7770] [G loss: 41.7037]
# [Epoch 63/500] [Batch 0/26] [D loss: -33.1770] [G loss: 44.8166]
# [Epoch 64/500] [Batch 0/26] [D loss: -37.8710] [G loss: 45.7538]
# [Epoch 65/500] [Batch 0/26] [D loss: -38.0773] [G loss: 35.1269]
# [Epoch 66/500] [Batch 0/26] [D loss: -43.8269] [G loss: 38.9658]
# [Epoch 67/500] [Batch 0/26] [D loss: -41.2402] [G loss: 37.2401]
# [Epoch 68/500] [Batch 0/26] [D loss: -39.0457] [G loss: 37.3270]
# [Epoch 69/500] [Batch 0/26] [D loss: -49.0850] [G loss: 40.3961]
# [Epoch 70/500] [Batch 0/26] [D loss: -38.4904] [G loss: 5.4187]
# [Epoch 71/500] [Batch 0/26] [D loss: -38.5965] [G loss: 38.9182]
# [Epoch 72/500] [Batch 0/26] [D loss: -44.9307] [G loss: 38.0403]
# [Epoch 73/500] [Batch 0/26] [D loss: -39.9514] [G loss: 33.9493]
# [Epoch 74/500] [Batch 0/26] [D loss: -36.5913] [G loss: 27.7294]
# [Epoch 75/500] [Batch 0/26] [D loss: -43.3580] [G loss: 43.5458]
# [Epoch 76/500] [Batch 0/26] [D loss: -41.7491] [G loss: 46.0251]
# [Epoch 77/500] [Batch 0/26] [D loss: -33.9369] [G loss: 34.7864]
# [Epoch 78/500] [Batch 0/26] [D loss: -37.6835] [G loss: 43.8295]
# [Epoch 79/500] [Batch 0/26] [D loss: -42.1739] [G loss: 39.6429]
# [Epoch 80/500] [Batch 0/26] [D loss: -36.4394] [G loss: 40.8170]
# [Epoch 81/500] [Batch 0/26] [D loss: -29.6996] [G loss: 32.8275]
# [Epoch 82/500] [Batch 0/26] [D loss: -33.9004] [G loss: 36.6640]
# [Epoch 83/500] [Batch 0/26] [D loss: -41.5451] [G loss: 23.0945]
# [Epoch 84/500] [Batch 0/26] [D loss: -42.2119] [G loss: 45.8082]
# [Epoch 85/500] [Batch 0/26] [D loss: -25.2513] [G loss: 18.8275]
# [Epoch 86/500] [Batch 0/26] [D loss: -43.7498] [G loss: 32.9481]
# [Epoch 87/500] [Batch 0/26] [D loss: -44.2074] [G loss: 33.5058]
# [Epoch 88/500] [Batch 0/26] [D loss: -42.9430] [G loss: 32.9371]
# [Epoch 89/500] [Batch 0/26] [D loss: -45.2539] [G loss: 42.1776]
# [Epoch 90/500] [Batch 0/26] [D loss: -48.9369] [G loss: 28.8401]
# [Epoch 91/500] [Batch 0/26] [D loss: -40.6171] [G loss: 39.2737]
# [Epoch 92/500] [Batch 0/26] [D loss: -45.5845] [G loss: 41.5390]
# [Epoch 93/500] [Batch 0/26] [D loss: -34.9823] [G loss: 37.3970]
# [Epoch 94/500] [Batch 0/26] [D loss: -43.0768] [G loss: 40.4799]
# [Epoch 95/500] [Batch 0/26] [D loss: -43.9613] [G loss: 44.8481]
# [Epoch 96/500] [Batch 0/26] [D loss: -39.8498] [G loss: 40.9080]
# [Epoch 97/500] [Batch 0/26] [D loss: -35.0623] [G loss: 48.4247]
# [Epoch 98/500] [Batch 0/26] [D loss: -40.9498] [G loss: 37.3589]
# [Epoch 99/500] [Batch 0/26] [D loss: -27.6632] [G loss: 46.6448]
# [Epoch 100/500] [Batch 0/26] [D loss: -37.2107] [G loss: 47.7360]
# Lowered Generator learning rate to 8e-05 at epoch 100!
# [Epoch 101/500] [Batch 0/26] [D loss: -41.3837] [G loss: 33.2558]
# [Epoch 102/500] [Batch 0/26] [D loss: -34.0161] [G loss: 33.2543]
# [Epoch 103/500] [Batch 0/26] [D loss: -38.3816] [G loss: 40.0308]
# [Epoch 104/500] [Batch 0/26] [D loss: -37.6877] [G loss: 20.7736]
# [Epoch 105/500] [Batch 0/26] [D loss: -43.2102] [G loss: 31.1806]
# [Epoch 106/500] [Batch 0/26] [D loss: -39.2853] [G loss: 17.6310]
# [Epoch 107/500] [Batch 0/26] [D loss: -43.8332] [G loss: 36.8874]
# [Epoch 108/500] [Batch 0/26] [D loss: -33.5256] [G loss: 24.9074]
# [Epoch 109/500] [Batch 0/26] [D loss: -28.7388] [G loss: 33.4014]
# [Epoch 110/500] [Batch 0/26] [D loss: -36.7390] [G loss: 35.9294]
# [Epoch 111/500] [Batch 0/26] [D loss: -43.6173] [G loss: 37.3581]
# [Epoch 112/500] [Batch 0/26] [D loss: -33.9479] [G loss: 19.2479]
# [Epoch 113/500] [Batch 0/26] [D loss: -47.2505] [G loss: 20.9519]
# [Epoch 114/500] [Batch 0/26] [D loss: -42.4410] [G loss: 46.4924]
# [Epoch 115/500] [Batch 0/26] [D loss: -34.0228] [G loss: 36.2163]
# [Epoch 116/500] [Batch 0/26] [D loss: -42.1931] [G loss: 33.9682]
# [Epoch 117/500] [Batch 0/26] [D loss: -45.9019] [G loss: 23.8748]
# [Epoch 118/500] [Batch 0/26] [D loss: -38.8137] [G loss: 32.3372]
# [Epoch 119/500] [Batch 0/26] [D loss: -37.4812] [G loss: 32.4309]
# [Epoch 120/500] [Batch 0/26] [D loss: -48.5424] [G loss: 42.8174]
# [Epoch 121/500] [Batch 0/26] [D loss: -33.2302] [G loss: 9.3564]
# [Epoch 122/500] [Batch 0/26] [D loss: -42.7528] [G loss: 42.1855]
# [Epoch 123/500] [Batch 0/26] [D loss: -38.5471] [G loss: 40.7181]
# [Epoch 124/500] [Batch 0/26] [D loss: -34.9926] [G loss: 35.8847]
# [Epoch 125/500] [Batch 0/26] [D loss: -36.1931] [G loss: 28.5018]
# [Epoch 126/500] [Batch 0/26] [D loss: -45.2586] [G loss: 37.2347]
# [Epoch 127/500] [Batch 0/26] [D loss: -32.3162] [G loss: 24.8270]
# [Epoch 128/500] [Batch 0/26] [D loss: -37.8087] [G loss: 40.3964]
# [Epoch 129/500] [Batch 0/26] [D loss: -40.5791] [G loss: 36.0944]
# [Epoch 130/500] [Batch 0/26] [D loss: -44.7920] [G loss: 38.5134]
# Generator beta1 updated to 0.2.
# [Epoch 131/500] [Batch 0/26] [D loss: -43.4354] [G loss: 37.6597]
# [Epoch 132/500] [Batch 0/26] [D loss: -36.8505] [G loss: 21.8171]
# [Epoch 133/500] [Batch 0/26] [D loss: -41.2686] [G loss: 29.3986]
# [Epoch 134/500] [Batch 0/26] [D loss: -38.2552] [G loss: 37.0668]
# [Epoch 135/500] [Batch 0/26] [D loss: -37.2515] [G loss: 38.3157]
# [Epoch 136/500] [Batch 0/26] [D loss: -40.4980] [G loss: 44.6061]
# [Epoch 137/500] [Batch 0/26] [D loss: -41.3347] [G loss: 4.1593]
# [Epoch 138/500] [Batch 0/26] [D loss: -38.9995] [G loss: 40.1522]
# [Epoch 139/500] [Batch 0/26] [D loss: -47.6170] [G loss: 40.9492]
# [Epoch 140/500] [Batch 0/26] [D loss: -47.9063] [G loss: 41.5927]
# [Epoch 141/500] [Batch 0/26] [D loss: -37.9832] [G loss: 41.3081]
# [Epoch 142/500] [Batch 0/26] [D loss: -48.5169] [G loss: 29.4235]
# [Epoch 143/500] [Batch 0/26] [D loss: -41.5966] [G loss: 38.8551]
# [Epoch 144/500] [Batch 0/26] [D loss: -33.4239] [G loss: 28.6709]
# [Epoch 145/500] [Batch 0/26] [D loss: -41.0833] [G loss: 23.4280]
# [Epoch 146/500] [Batch 0/26] [D loss: -36.2702] [G loss: 33.9932]
# [Epoch 147/500] [Batch 0/26] [D loss: -43.2547] [G loss: 27.5194]
# [Epoch 148/500] [Batch 0/26] [D loss: -45.4941] [G loss: 34.1925]
# [Epoch 149/500] [Batch 0/26] [D loss: -41.1553] [G loss: 20.3361]
# [Epoch 150/500] [Batch 0/26] [D loss: -31.6900] [G loss: 32.1150]
# [Epoch 151/500] [Batch 0/26] [D loss: -41.5024] [G loss: 32.2506]
# [Epoch 152/500] [Batch 0/26] [D loss: -44.3365] [G loss: 43.4412]
# [Epoch 153/500] [Batch 0/26] [D loss: -33.2433] [G loss: 34.4619]
# [Epoch 154/500] [Batch 0/26] [D loss: -35.2356] [G loss: 36.3957]
# [Epoch 155/500] [Batch 0/26] [D loss: -40.9968] [G loss: 35.1178]
# [Epoch 156/500] [Batch 0/26] [D loss: -42.4303] [G loss: 35.2593]
# [Epoch 157/500] [Batch 0/26] [D loss: -43.4020] [G loss: 35.3478]
# [Epoch 158/500] [Batch 0/26] [D loss: -43.4470] [G loss: 42.2714]
# [Epoch 159/500] [Batch 0/26] [D loss: -35.8338] [G loss: 30.2675]
# [Epoch 160/500] [Batch 0/26] [D loss: -44.4698] [G loss: 33.0603]
# [Epoch 161/500] [Batch 0/26] [D loss: -36.7497] [G loss: 48.1986]
# [Epoch 162/500] [Batch 0/26] [D loss: -43.2577] [G loss: 40.3233]
# [Epoch 163/500] [Batch 0/26] [D loss: -48.3864] [G loss: 43.2310]
# [Epoch 164/500] [Batch 0/26] [D loss: -43.4454] [G loss: 28.2395]
# [Epoch 165/500] [Batch 0/26] [D loss: -33.9648] [G loss: 21.1021]
# [Epoch 166/500] [Batch 0/26] [D loss: -40.0647] [G loss: 33.8076]
# [Epoch 167/500] [Batch 0/26] [D loss: -41.3417] [G loss: 36.6604]
# [Epoch 168/500] [Batch 0/26] [D loss: -42.6630] [G loss: 35.2857]
# [Epoch 169/500] [Batch 0/26] [D loss: -44.2274] [G loss: 23.6578]
# [Epoch 170/500] [Batch 0/26] [D loss: -33.1774] [G loss: 37.5704]
# [Epoch 171/500] [Batch 0/26] [D loss: -42.5416] [G loss: 33.5090]
# [Epoch 172/500] [Batch 0/26] [D loss: -41.6934] [G loss: 32.1375]
# [Epoch 173/500] [Batch 0/26] [D loss: -45.6712] [G loss: 31.4103]
# [Epoch 174/500] [Batch 0/26] [D loss: -48.2607] [G loss: 43.3617]
# [Epoch 175/500] [Batch 0/26] [D loss: -37.8567] [G loss: 17.5467]
# [Epoch 176/500] [Batch 0/26] [D loss: -26.2303] [G loss: 25.3250]
# [Epoch 177/500] [Batch 0/26] [D loss: -37.8175] [G loss: 33.1241]
# [Epoch 178/500] [Batch 0/26] [D loss: -33.0110] [G loss: 27.1421]
# [Epoch 179/500] [Batch 0/26] [D loss: -43.2078] [G loss: 25.3035]
# [Epoch 180/500] [Batch 0/26] [D loss: -39.4309] [G loss: 43.7660]
# [Epoch 181/500] [Batch 0/26] [D loss: -33.9895] [G loss: 27.4283]
# [Epoch 182/500] [Batch 0/26] [D loss: -46.6999] [G loss: 46.2230]
# [Epoch 183/500] [Batch 0/26] [D loss: -37.7849] [G loss: 23.6570]
# [Epoch 184/500] [Batch 0/26] [D loss: -45.7114] [G loss: 30.1645]
# [Epoch 185/500] [Batch 0/26] [D loss: -50.2345] [G loss: 22.8325]
# [Epoch 186/500] [Batch 0/26] [D loss: -44.9107] [G loss: 37.6188]
# [Epoch 187/500] [Batch 0/26] [D loss: -36.9527] [G loss: 36.2371]
# [Epoch 188/500] [Batch 0/26] [D loss: -52.8696] [G loss: 36.4004]
# [Epoch 189/500] [Batch 0/26] [D loss: -45.1576] [G loss: 38.2673]
# [Epoch 190/500] [Batch 0/26] [D loss: -42.5753] [G loss: 28.5597]
# [Epoch 191/500] [Batch 0/26] [D loss: -46.7828] [G loss: 41.3521]
# [Epoch 192/500] [Batch 0/26] [D loss: -42.2902] [G loss: 22.6240]
# [Epoch 193/500] [Batch 0/26] [D loss: -39.9447] [G loss: 34.6416]
# [Epoch 194/500] [Batch 0/26] [D loss: -31.3696] [G loss: 24.5281]
# [Epoch 195/500] [Batch 0/26] [D loss: -41.5918] [G loss: 36.9096]
# [Epoch 196/500] [Batch 0/26] [D loss: -48.9357] [G loss: 35.3083]
# [Epoch 197/500] [Batch 0/26] [D loss: -38.9180] [G loss: 34.2801]
# [Epoch 198/500] [Batch 0/26] [D loss: -26.5337] [G loss: 28.9068]
# [Epoch 199/500] [Batch 0/26] [D loss: -46.1558] [G loss: 29.8140]
# Lowered Generator learning rate to 4.8e-05 at epoch 199!
# [Epoch 200/500] [Batch 0/26] [D loss: -40.3279] [G loss: 36.6967]
# [Epoch 201/500] [Batch 0/26] [D loss: -49.9720] [G loss: 42.2496]
# [Epoch 202/500] [Batch 0/26] [D loss: -46.9452] [G loss: 12.5734]
# [Epoch 203/500] [Batch 0/26] [D loss: -40.7714] [G loss: 35.4497]
# [Epoch 204/500] [Batch 0/26] [D loss: -38.3751] [G loss: 45.0699]
# [Epoch 205/500] [Batch 0/26] [D loss: -48.7995] [G loss: 38.6542]
# [Epoch 206/500] [Batch 0/26] [D loss: -37.5844] [G loss: 22.0945]
# [Epoch 207/500] [Batch 0/26] [D loss: -50.0062] [G loss: 40.2586]
# [Epoch 208/500] [Batch 0/26] [D loss: -41.9950] [G loss: 25.8570]
# [Epoch 209/500] [Batch 0/26] [D loss: -38.2109] [G loss: 35.2637]
# [Epoch 210/500] [Batch 0/26] [D loss: -45.0506] [G loss: 41.4988]
# [Epoch 211/500] [Batch 0/26] [D loss: -37.1080] [G loss: 23.0879]
# [Epoch 212/500] [Batch 0/26] [D loss: -43.0977] [G loss: 30.6682]
# [Epoch 213/500] [Batch 0/26] [D loss: -41.3362] [G loss: 44.0835]
# [Epoch 214/500] [Batch 0/26] [D loss: -46.4878] [G loss: 38.0004]
# [Epoch 215/500] [Batch 0/26] [D loss: -38.3630] [G loss: 18.8975]
# [Epoch 216/500] [Batch 0/26] [D loss: -45.8848] [G loss: 33.7821]
# [Epoch 217/500] [Batch 0/26] [D loss: -38.6973] [G loss: 27.5278]
# [Epoch 218/500] [Batch 0/26] [D loss: -45.9850] [G loss: 33.0403]
# [Epoch 219/500] [Batch 0/26] [D loss: -43.4504] [G loss: 39.6316]
# [Epoch 220/500] [Batch 0/26] [D loss: -45.9483] [G loss: 37.8842]
# [Epoch 221/500] [Batch 0/26] [D loss: -36.9298] [G loss: 31.1816]
# [Epoch 222/500] [Batch 0/26] [D loss: -43.0427] [G loss: 33.1287]
# [Epoch 223/500] [Batch 0/26] [D loss: -46.5971] [G loss: 25.7958]
# [Epoch 224/500] [Batch 0/26] [D loss: -37.0812] [G loss: 31.9680]
# [Epoch 225/500] [Batch 0/26] [D loss: -35.9917] [G loss: 36.5312]
# [Epoch 226/500] [Batch 0/26] [D loss: -47.4744] [G loss: 38.0461]
# [Epoch 227/500] [Batch 0/26] [D loss: -44.5736] [G loss: 34.2097]
# [Epoch 228/500] [Batch 0/26] [D loss: -44.1906] [G loss: 25.6924]
# [Epoch 229/500] [Batch 0/26] [D loss: -45.5948] [G loss: 32.5774]
# [Epoch 230/500] [Batch 0/26] [D loss: -38.4107] [G loss: 32.8040]
# [Epoch 231/500] [Batch 0/26] [D loss: -41.8418] [G loss: 43.8275]
# [Epoch 232/500] [Batch 0/26] [D loss: -38.7524] [G loss: 39.6077]
# [Epoch 233/500] [Batch 0/26] [D loss: -53.5739] [G loss: 35.8623]
# [Epoch 234/500] [Batch 0/26] [D loss: -44.9326] [G loss: 29.8791]
# [Epoch 235/500] [Batch 0/26] [D loss: -53.1613] [G loss: 29.7093]
# [Epoch 236/500] [Batch 0/26] [D loss: -44.9672] [G loss: 37.1932]
# [Epoch 237/500] [Batch 0/26] [D loss: -39.6844] [G loss: 42.2937]
# [Epoch 238/500] [Batch 0/26] [D loss: -48.7025] [G loss: 36.6175]
# [Epoch 239/500] [Batch 0/26] [D loss: -47.1273] [G loss: 42.4164]
# [Epoch 240/500] [Batch 0/26] [D loss: -43.4973] [G loss: 24.5341]
# [Epoch 241/500] [Batch 0/26] [D loss: -45.8571] [G loss: 22.6999]
# [Epoch 242/500] [Batch 0/26] [D loss: -30.4682] [G loss: 25.8820]
# [Epoch 243/500] [Batch 0/26] [D loss: -44.4640] [G loss: 30.0778]
# [Epoch 244/500] [Batch 0/26] [D loss: -40.8785] [G loss: 30.6378]
# [Epoch 245/500] [Batch 0/26] [D loss: -48.6544] [G loss: 38.7325]
# [Epoch 246/500] [Batch 0/26] [D loss: -43.9228] [G loss: 47.1988]
# [Epoch 247/500] [Batch 0/26] [D loss: -41.6687] [G loss: 29.6842]
# [Epoch 248/500] [Batch 0/26] [D loss: -49.5238] [G loss: 43.0744]
# [Epoch 249/500] [Batch 0/26] [D loss: -48.5918] [G loss: 44.9689]
# [Epoch 250/500] [Batch 0/26] [D loss: -44.0685] [G loss: 36.3535]
# [Epoch 251/500] [Batch 0/26] [D loss: -42.7817] [G loss: 35.6562]
# [Epoch 252/500] [Batch 0/26] [D loss: -45.2369] [G loss: 40.3758]
# [Epoch 253/500] [Batch 0/26] [D loss: -40.2463] [G loss: 35.3972]
# [Epoch 254/500] [Batch 0/26] [D loss: -42.1055] [G loss: 33.7310]
# [Epoch 255/500] [Batch 0/26] [D loss: -43.5191] [G loss: 21.4681]
# [Epoch 256/500] [Batch 0/26] [D loss: -41.0513] [G loss: 38.5391]
# [Epoch 257/500] [Batch 0/26] [D loss: -45.3123] [G loss: 34.5591]
# [Epoch 258/500] [Batch 0/26] [D loss: -46.6630] [G loss: 40.4232]
# [Epoch 259/500] [Batch 0/26] [D loss: -46.9237] [G loss: 31.0358]
# [Epoch 260/500] [Batch 0/26] [D loss: -44.7879] [G loss: 37.4398]
# [Epoch 261/500] [Batch 0/26] [D loss: -42.0419] [G loss: 32.3480]
# [Epoch 262/500] [Batch 0/26] [D loss: -46.8051] [G loss: 39.2819]
# [Epoch 263/500] [Batch 0/26] [D loss: -42.1874] [G loss: 41.9951]
# [Epoch 264/500] [Batch 0/26] [D loss: -46.6748] [G loss: 27.4094]
# [Epoch 265/500] [Batch 0/26] [D loss: -43.9130] [G loss: 35.1616]
# [Epoch 266/500] [Batch 0/26] [D loss: -50.5828] [G loss: 37.0136]
# [Epoch 267/500] [Batch 0/26] [D loss: -45.3630] [G loss: 39.9651]
# [Epoch 268/500] [Batch 0/26] [D loss: -51.2188] [G loss: 41.7654]
# [Epoch 269/500] [Batch 0/26] [D loss: -39.1016] [G loss: 24.8585]
# [Epoch 270/500] [Batch 0/26] [D loss: -43.3152] [G loss: 41.0037]
# [Epoch 271/500] [Batch 0/26] [D loss: -41.7313] [G loss: 39.1957]
# [Epoch 272/500] [Batch 0/26] [D loss: -52.2334] [G loss: 28.8541]
# [Epoch 273/500] [Batch 0/26] [D loss: -52.5494] [G loss: 41.5295]
# [Epoch 274/500] [Batch 0/26] [D loss: -45.1268] [G loss: 35.1033]
# [Epoch 275/500] [Batch 0/26] [D loss: -47.5108] [G loss: 19.8964]
# [Epoch 276/500] [Batch 0/26] [D loss: -46.0623] [G loss: 37.5217]
# [Epoch 277/500] [Batch 0/26] [D loss: -42.5149] [G loss: 36.8319]
# [Epoch 278/500] [Batch 0/26] [D loss: -43.4599] [G loss: 32.7041]
# [Epoch 279/500] [Batch 0/26] [D loss: -45.1812] [G loss: 23.4496]
# [Epoch 280/500] [Batch 0/26] [D loss: -34.6604] [G loss: 17.1069]
# [Epoch 281/500] [Batch 0/26] [D loss: -43.9551] [G loss: 43.0653]
# [Epoch 282/500] [Batch 0/26] [D loss: -41.6699] [G loss: 12.0453]
# [Epoch 283/500] [Batch 0/26] [D loss: -37.8135] [G loss: 21.5304]
# [Epoch 284/500] [Batch 0/26] [D loss: -39.6360] [G loss: 32.9028]
# [Epoch 285/500] [Batch 0/26] [D loss: -52.2743] [G loss: 34.6873]
# [Epoch 286/500] [Batch 0/26] [D loss: -43.7818] [G loss: 23.5658]
# [Epoch 287/500] [Batch 0/26] [D loss: -41.2461] [G loss: 13.3559]
# [Epoch 288/500] [Batch 0/26] [D loss: -45.9976] [G loss: 46.0558]
# [Epoch 289/500] [Batch 0/26] [D loss: -40.4698] [G loss: 39.7555]
# [Epoch 290/500] [Batch 0/26] [D loss: -49.9461] [G loss: 45.8531]
# [Epoch 291/500] [Batch 0/26] [D loss: -45.8056] [G loss: 37.9443]
# [Epoch 292/500] [Batch 0/26] [D loss: -37.3106] [G loss: 41.1545]
# [Epoch 293/500] [Batch 0/26] [D loss: -46.2977] [G loss: 30.9532]
# [Epoch 294/500] [Batch 0/26] [D loss: -49.5204] [G loss: 31.7987]
# [Epoch 295/500] [Batch 0/26] [D loss: -46.8047] [G loss: 30.5203]
# [Epoch 296/500] [Batch 0/26] [D loss: -41.8017] [G loss: 28.4741]
# [Epoch 297/500] [Batch 0/26] [D loss: -42.9574] [G loss: 43.0779]
# [Epoch 298/500] [Batch 0/26] [D loss: -48.1015] [G loss: 37.9570]
# [Epoch 299/500] [Batch 0/26] [D loss: -52.7506] [G loss: 39.1154]
# [Epoch 300/500] [Batch 0/26] [D loss: -51.0126] [G loss: 33.1784]
# [Epoch 301/500] [Batch 0/26] [D loss: -40.9093] [G loss: 35.1441]
# [Epoch 302/500] [Batch 0/26] [D loss: -50.7148] [G loss: 44.9078]
# [Epoch 303/500] [Batch 0/26] [D loss: -49.5905] [G loss: 39.8999]
# [Epoch 304/500] [Batch 0/26] [D loss: -40.8514] [G loss: 42.4109]
# [Epoch 305/500] [Batch 0/26] [D loss: -48.5146] [G loss: 41.3978]
# [Epoch 306/500] [Batch 0/26] [D loss: -36.6306] [G loss: 32.2079]
# [Epoch 307/500] [Batch 0/26] [D loss: -44.6440] [G loss: 40.6453]
# [Epoch 308/500] [Batch 0/26] [D loss: -47.1936] [G loss: 18.7836]
# [Epoch 309/500] [Batch 0/26] [D loss: -45.7528] [G loss: 39.9331]
# [Epoch 310/500] [Batch 0/26] [D loss: -45.7729] [G loss: 32.5551]
# [Epoch 311/500] [Batch 0/26] [D loss: -47.7519] [G loss: 43.6858]
# [Epoch 312/500] [Batch 0/26] [D loss: -50.0505] [G loss: 22.7540]
# [Epoch 313/500] [Batch 0/26] [D loss: -33.8216] [G loss: 44.9748]
# [Epoch 314/500] [Batch 0/26] [D loss: -37.2057] [G loss: 21.5020]
# [Epoch 315/500] [Batch 0/26] [D loss: -50.2833] [G loss: 20.9527]
# [Epoch 316/500] [Batch 0/26] [D loss: -43.0527] [G loss: 32.9153]
# [Epoch 317/500] [Batch 0/26] [D loss: -38.4989] [G loss: 43.3995]
# [Epoch 318/500] [Batch 0/26] [D loss: -47.7014] [G loss: 30.0318]
# [Epoch 319/500] [Batch 0/26] [D loss: -46.4021] [G loss: 40.2247]
# [Epoch 320/500] [Batch 0/26] [D loss: -44.5122] [G loss: 40.5150]
# [Epoch 321/500] [Batch 0/26] [D loss: -49.3892] [G loss: 30.2359]
# [Epoch 322/500] [Batch 0/26] [D loss: -45.6929] [G loss: 41.9212]
# [Epoch 323/500] [Batch 0/26] [D loss: -47.6991] [G loss: 40.9336]
# [Epoch 324/500] [Batch 0/26] [D loss: -42.3666] [G loss: 39.1906]
# [Epoch 325/500] [Batch 0/26] [D loss: -38.7740] [G loss: 35.4051]
# [Epoch 326/500] [Batch 0/26] [D loss: -46.0344] [G loss: 35.2347]
# [Epoch 327/500] [Batch 0/26] [D loss: -42.0747] [G loss: 43.1916]
# [Epoch 328/500] [Batch 0/26] [D loss: -44.1601] [G loss: 32.7520]
# [Epoch 329/500] [Batch 0/26] [D loss: -47.5034] [G loss: 29.7160]
# [Epoch 330/500] [Batch 0/26] [D loss: -51.8666] [G loss: 38.1559]
# [Epoch 331/500] [Batch 0/26] [D loss: -53.9991] [G loss: 32.4208]
# [Epoch 332/500] [Batch 0/26] [D loss: -44.6051] [G loss: 36.9507]
# [Epoch 333/500] [Batch 0/26] [D loss: -44.4065] [G loss: 33.6177]
# [Epoch 334/500] [Batch 0/26] [D loss: -48.8426] [G loss: 24.4761]
# [Epoch 335/500] [Batch 0/26] [D loss: -49.2473] [G loss: 28.8565]
# [Epoch 336/500] [Batch 0/26] [D loss: -42.5441] [G loss: 37.5932]
# [Epoch 337/500] [Batch 0/26] [D loss: -45.4078] [G loss: 31.0168]
# [Epoch 338/500] [Batch 0/26] [D loss: -45.4670] [G loss: 33.6206]
# [Epoch 339/500] [Batch 0/26] [D loss: -48.2005] [G loss: 43.6804]
# [Epoch 340/500] [Batch 0/26] [D loss: -51.7285] [G loss: 42.1816]
# [Epoch 341/500] [Batch 0/26] [D loss: -37.0972] [G loss: 33.5490]
# [Epoch 342/500] [Batch 0/26] [D loss: -40.4270] [G loss: 35.9808]
# [Epoch 343/500] [Batch 0/26] [D loss: -51.9874] [G loss: 36.0737]
# [Epoch 344/500] [Batch 0/26] [D loss: -44.0218] [G loss: 22.2405]
# [Epoch 345/500] [Batch 0/26] [D loss: -52.9208] [G loss: 44.6815]
# [Epoch 346/500] [Batch 0/26] [D loss: -51.0499] [G loss: 37.4632]
# [Epoch 347/500] [Batch 0/26] [D loss: -41.6606] [G loss: 25.8693]
# [Epoch 348/500] [Batch 0/26] [D loss: -51.0608] [G loss: 38.3973]
# [Epoch 349/500] [Batch 0/26] [D loss: -45.1151] [G loss: 45.1106]
# [Epoch 350/500] [Batch 0/26] [D loss: -39.5272] [G loss: 42.9944]
# [Epoch 351/500] [Batch 0/26] [D loss: -45.6055] [G loss: 38.9866]
# [Epoch 352/500] [Batch 0/26] [D loss: -50.1796] [G loss: 16.6226]
# [Epoch 353/500] [Batch 0/26] [D loss: -47.9935] [G loss: 42.5403]
# [Epoch 354/500] [Batch 0/26] [D loss: -57.5215] [G loss: 33.4727]
# [Epoch 355/500] [Batch 0/26] [D loss: -45.6876] [G loss: 31.1653]
# [Epoch 356/500] [Batch 0/26] [D loss: -44.5135] [G loss: 42.0441]
# [Epoch 357/500] [Batch 0/26] [D loss: -53.8019] [G loss: 23.3882]
# [Epoch 358/500] [Batch 0/26] [D loss: -52.9139] [G loss: 42.2379]
# [Epoch 359/500] [Batch 0/26] [D loss: -41.2764] [G loss: 37.0030]
# [Epoch 360/500] [Batch 0/26] [D loss: -47.2042] [G loss: 42.9663]
# [Epoch 361/500] [Batch 0/26] [D loss: -28.8752] [G loss: 45.0088]
# [Epoch 362/500] [Batch 0/26] [D loss: -49.0510] [G loss: 29.9911]
# [Epoch 363/500] [Batch 0/26] [D loss: -36.7241] [G loss: 44.3627]
# [Epoch 364/500] [Batch 0/26] [D loss: -50.1334] [G loss: 36.4798]
# [Epoch 365/500] [Batch 0/26] [D loss: -43.6570] [G loss: 39.5851]
# [Epoch 366/500] [Batch 0/26] [D loss: -39.8786] [G loss: 44.4285]
# [Epoch 367/500] [Batch 0/26] [D loss: -50.5294] [G loss: 41.6635]
# [Epoch 368/500] [Batch 0/26] [D loss: -60.1388] [G loss: 39.4155]
# [Epoch 369/500] [Batch 0/26] [D loss: -41.2891] [G loss: 21.2420]
# [Epoch 370/500] [Batch 0/26] [D loss: -44.8361] [G loss: 39.0403]
# [Epoch 371/500] [Batch 0/26] [D loss: -47.2260] [G loss: 38.4171]
# [Epoch 372/500] [Batch 0/26] [D loss: -47.0879] [G loss: 39.4678]
# [Epoch 373/500] [Batch 0/26] [D loss: -46.5186] [G loss: 40.6150]
# [Epoch 374/500] [Batch 0/26] [D loss: -57.9830] [G loss: 41.5460]
# [Epoch 375/500] [Batch 0/26] [D loss: -49.1689] [G loss: 43.9646]
# [Epoch 376/500] [Batch 0/26] [D loss: -42.2027] [G loss: 38.3339]
# [Epoch 377/500] [Batch 0/26] [D loss: -34.6868] [G loss: 25.7319]
# [Epoch 378/500] [Batch 0/26] [D loss: -45.9087] [G loss: 44.6394]
# [Epoch 379/500] [Batch 0/26] [D loss: -41.8316] [G loss: 42.3314]
# [Epoch 380/500] [Batch 0/26] [D loss: -55.2192] [G loss: 26.7769]
# [Epoch 381/500] [Batch 0/26] [D loss: -43.7443] [G loss: 20.7550]
# [Epoch 382/500] [Batch 0/26] [D loss: -45.5830] [G loss: 44.8073]
# [Epoch 383/500] [Batch 0/26] [D loss: -49.8699] [G loss: 33.3122]
# [Epoch 384/500] [Batch 0/26] [D loss: -48.6166] [G loss: 40.9449]
# [Epoch 385/500] [Batch 0/26] [D loss: -45.1960] [G loss: 20.5313]
# [Epoch 386/500] [Batch 0/26] [D loss: -50.2539] [G loss: 34.3775]
# [Epoch 387/500] [Batch 0/26] [D loss: -46.0152] [G loss: 22.0406]
# [Epoch 388/500] [Batch 0/26] [D loss: -41.1695] [G loss: 34.8174]
# [Epoch 389/500] [Batch 0/26] [D loss: -37.6376] [G loss: 27.3928]
# [Epoch 390/500] [Batch 0/26] [D loss: -43.3567] [G loss: 32.7133]
# [Epoch 391/500] [Batch 0/26] [D loss: -56.0153] [G loss: 46.1180]
# [Epoch 392/500] [Batch 0/26] [D loss: -45.6123] [G loss: 37.3591]
# [Epoch 393/500] [Batch 0/26] [D loss: -43.8329] [G loss: 22.5058]
# [Epoch 394/500] [Batch 0/26] [D loss: -47.7943] [G loss: 27.7133]
# [Epoch 395/500] [Batch 0/26] [D loss: -47.8136] [G loss: 32.8399]
# [Epoch 396/500] [Batch 0/26] [D loss: -50.4336] [G loss: 32.5258]
# [Epoch 397/500] [Batch 0/26] [D loss: -43.4390] [G loss: 42.6366]
# [Epoch 398/500] [Batch 0/26] [D loss: -44.2220] [G loss: 32.6149]
# [Epoch 399/500] [Batch 0/26] [D loss: -35.5274] [G loss: 34.0994]
# [Epoch 400/500] [Batch 0/26] [D loss: -44.6145] [G loss: 40.9351]
# [Epoch 401/500] [Batch 0/26] [D loss: -50.9644] [G loss: 43.9632]
# [Epoch 402/500] [Batch 0/26] [D loss: -55.2583] [G loss: 42.9455]
# [Epoch 403/500] [Batch 0/26] [D loss: -50.1364] [G loss: 34.5617]
# [Epoch 404/500] [Batch 0/26] [D loss: -47.3686] [G loss: 29.4518]
# [Epoch 405/500] [Batch 0/26] [D loss: -49.7263] [G loss: 35.1826]
# [Epoch 406/500] [Batch 0/26] [D loss: -41.4259] [G loss: 31.3993]
# [Epoch 407/500] [Batch 0/26] [D loss: -44.4999] [G loss: 36.8519]
# [Epoch 408/500] [Batch 0/26] [D loss: -46.3647] [G loss: 43.9679]
# [Epoch 409/500] [Batch 0/26] [D loss: -50.0670] [G loss: 38.8060]
# [Epoch 410/500] [Batch 0/26] [D loss: -36.1121] [G loss: 26.8552]
# [Epoch 411/500] [Batch 0/26] [D loss: -36.2754] [G loss: 22.0814]
# [Epoch 412/500] [Batch 0/26] [D loss: -44.7594] [G loss: 35.7550]
# [Epoch 413/500] [Batch 0/26] [D loss: -47.0081] [G loss: 34.9122]
# [Epoch 414/500] [Batch 0/26] [D loss: -40.9722] [G loss: 42.3273]
# [Epoch 415/500] [Batch 0/26] [D loss: -51.3690] [G loss: 36.1129]
# [Epoch 416/500] [Batch 0/26] [D loss: -47.5841] [G loss: 43.9757]
# [Epoch 417/500] [Batch 0/26] [D loss: -45.7150] [G loss: 23.4218]
# [Epoch 418/500] [Batch 0/26] [D loss: -52.8958] [G loss: 42.8523]
# [Epoch 419/500] [Batch 0/26] [D loss: -45.4708] [G loss: 20.9246]
# [Epoch 420/500] [Batch 0/26] [D loss: -43.0189] [G loss: 35.7345]
# [Epoch 421/500] [Batch 0/26] [D loss: -49.5248] [G loss: 25.1893]
# [Epoch 422/500] [Batch 0/26] [D loss: -45.0897] [G loss: 25.6092]
# [Epoch 423/500] [Batch 0/26] [D loss: -40.4876] [G loss: 41.6594]
# [Epoch 424/500] [Batch 0/26] [D loss: -56.1706] [G loss: 30.6809]
# [Epoch 425/500] [Batch 0/26] [D loss: -40.4412] [G loss: 33.9219]
# [Epoch 426/500] [Batch 0/26] [D loss: -47.6035] [G loss: 29.7775]
# [Epoch 427/500] [Batch 0/26] [D loss: -50.3542] [G loss: 45.6426]
# [Epoch 428/500] [Batch 0/26] [D loss: -46.9693] [G loss: 36.7923]
# [Epoch 429/500] [Batch 0/26] [D loss: -44.1014] [G loss: 37.2809]
# [Epoch 430/500] [Batch 0/26] [D loss: -51.9994] [G loss: 32.3847]
# [Epoch 431/500] [Batch 0/26] [D loss: -52.2716] [G loss: 37.1245]
# [Epoch 432/500] [Batch 0/26] [D loss: -54.3715] [G loss: 39.9425]
# [Epoch 433/500] [Batch 0/26] [D loss: -47.6217] [G loss: 35.9004]
# [Epoch 434/500] [Batch 0/26] [D loss: -54.7367] [G loss: 33.2021]
# [Epoch 435/500] [Batch 0/26] [D loss: -53.8008] [G loss: 27.6955]
# [Epoch 436/500] [Batch 0/26] [D loss: -46.0986] [G loss: 40.8702]
# [Epoch 437/500] [Batch 0/26] [D loss: -42.8475] [G loss: 34.0657]
# [Epoch 438/500] [Batch 0/26] [D loss: -51.7815] [G loss: 31.2178]
# [Epoch 439/500] [Batch 0/26] [D loss: -48.5721] [G loss: 25.3578]
# [Epoch 440/500] [Batch 0/26] [D loss: -43.4271] [G loss: 40.8009]
# [Epoch 441/500] [Batch 0/26] [D loss: -43.1785] [G loss: 42.7205]
# [Epoch 442/500] [Batch 0/26] [D loss: -47.5676] [G loss: 35.6756]
# [Epoch 443/500] [Batch 0/26] [D loss: -47.2174] [G loss: 35.5598]
# [Epoch 444/500] [Batch 0/26] [D loss: -46.0700] [G loss: 22.3362]
# [Epoch 445/500] [Batch 0/26] [D loss: -49.3609] [G loss: 35.3057]
# [Epoch 446/500] [Batch 0/26] [D loss: -42.9076] [G loss: 25.0460]
# [Epoch 447/500] [Batch 0/26] [D loss: -47.6370] [G loss: 29.9696]
# [Epoch 448/500] [Batch 0/26] [D loss: -45.4802] [G loss: 28.4235]
# [Epoch 449/500] [Batch 0/26] [D loss: -50.7323] [G loss: 32.0011]
# [Epoch 450/500] [Batch 0/26] [D loss: -55.7998] [G loss: 34.6766]
# [Epoch 451/500] [Batch 0/26] [D loss: -57.1469] [G loss: 40.0100]
# [Epoch 452/500] [Batch 0/26] [D loss: -43.9087] [G loss: 32.8968]
# [Epoch 453/500] [Batch 0/26] [D loss: -47.6622] [G loss: 38.4482]
# [Epoch 454/500] [Batch 0/26] [D loss: -49.9994] [G loss: 33.4013]
# [Epoch 455/500] [Batch 0/26] [D loss: -45.9354] [G loss: 43.0124]
# [Epoch 456/500] [Batch 0/26] [D loss: -46.5174] [G loss: 34.2680]
# [Epoch 457/500] [Batch 0/26] [D loss: -53.1598] [G loss: 41.8494]
# [Epoch 458/500] [Batch 0/26] [D loss: -60.0602] [G loss: 43.6863]
# [Epoch 459/500] [Batch 0/26] [D loss: -51.1119] [G loss: 37.4740]
# [Epoch 460/500] [Batch 0/26] [D loss: -50.0406] [G loss: 35.2031]
# [Epoch 461/500] [Batch 0/26] [D loss: -52.4879] [G loss: 35.2895]
# [Epoch 462/500] [Batch 0/26] [D loss: -44.8731] [G loss: 39.1053]
# [Epoch 463/500] [Batch 0/26] [D loss: -39.9453] [G loss: 42.7020]
# [Epoch 464/500] [Batch 0/26] [D loss: -51.1476] [G loss: 39.3442]
# [Epoch 465/500] [Batch 0/26] [D loss: -56.6315] [G loss: 37.7523]
# [Epoch 466/500] [Batch 0/26] [D loss: -50.6102] [G loss: 34.8600]
# [Epoch 467/500] [Batch 0/26] [D loss: -50.4219] [G loss: 41.6227]
# [Epoch 468/500] [Batch 0/26] [D loss: -48.9707] [G loss: 44.2793]
# [Epoch 469/500] [Batch 0/26] [D loss: -49.3769] [G loss: 43.4261]
# [Epoch 470/500] [Batch 0/26] [D loss: -40.5414] [G loss: 38.0300]
# [Epoch 471/500] [Batch 0/26] [D loss: -49.2110] [G loss: 34.2106]
# [Epoch 472/500] [Batch 0/26] [D loss: -49.7872] [G loss: 44.8322]
# [Epoch 473/500] [Batch 0/26] [D loss: -51.9659] [G loss: 34.4796]
# [Epoch 474/500] [Batch 0/26] [D loss: -46.8889] [G loss: 30.8051]
# [Epoch 475/500] [Batch 0/26] [D loss: -53.1744] [G loss: 44.8748]
# [Epoch 476/500] [Batch 0/26] [D loss: -52.2421] [G loss: 40.7809]
# [Epoch 477/500] [Batch 0/26] [D loss: -42.3841] [G loss: 45.3771]
# [Epoch 478/500] [Batch 0/26] [D loss: -53.8178] [G loss: 33.4052]
# [Epoch 479/500] [Batch 0/26] [D loss: -47.3404] [G loss: 25.2046]
# [Epoch 480/500] [Batch 0/26] [D loss: -54.0697] [G loss: 39.2540]
# [Epoch 481/500] [Batch 0/26] [D loss: -44.2523] [G loss: 31.0338]
# [Epoch 482/500] [Batch 0/26] [D loss: -56.2712] [G loss: 33.0564]
# [Epoch 483/500] [Batch 0/26] [D loss: -44.2933] [G loss: 43.2346]
# [Epoch 484/500] [Batch 0/26] [D loss: -52.3366] [G loss: 40.3129]
# [Epoch 485/500] [Batch 0/26] [D loss: -39.7746] [G loss: 30.4369]
# [Epoch 486/500] [Batch 0/26] [D loss: -48.3691] [G loss: 39.6364]
# [Epoch 487/500] [Batch 0/26] [D loss: -50.1348] [G loss: 35.5786]
# [Epoch 488/500] [Batch 0/26] [D loss: -54.3121] [G loss: 40.2793]
# [Epoch 489/500] [Batch 0/26] [D loss: -51.0792] [G loss: 40.9552]
# [Epoch 490/500] [Batch 0/26] [D loss: -37.6522] [G loss: 24.2793]
# [Epoch 491/500] [Batch 0/26] [D loss: -45.4238] [G loss: 38.0414]
# [Epoch 492/500] [Batch 0/26] [D loss: -50.4932] [G loss: 41.0048]
# [Epoch 493/500] [Batch 0/26] [D loss: -54.9435] [G loss: 39.7037]
# [Epoch 494/500] [Batch 0/26] [D loss: -47.2748] [G loss: 28.2729]
# [Epoch 495/500] [Batch 0/26] [D loss: -48.6261] [G loss: 40.5923]
# [Epoch 496/500] [Batch 0/26] [D loss: -48.7997] [G loss: 37.5280]
# [Epoch 497/500] [Batch 0/26] [D loss: -46.6810] [G loss: 30.5567]
# [Epoch 498/500] [Batch 0/26] [D loss: -53.1409] [G loss: 27.3346]
# [Epoch 499/500] [Batch 0/26] [D loss: -48.7958] [G loss: 34.1359]
# Training completed.

# %%
# Plot the loss graph to identify possible collapses and/or weakening G/D
import pandas as pd
import matplotlib.pyplot as plt
import re

with open(r"E:\Projects\WGAN-GP_CarBrandSocials\Logs\28_4_25.log", "r") as f:
    lines = f.readlines()

logs_ext_2804 = [re.findall(r"\[Epoch (\d+)/\d+\].*?\[D loss: ([\-\d.]+)\].*?\[G loss: ([\-\d.]+)\]", line)[0]
               for line in lines if "D loss" in line and "G loss" in line]

logs_ext_2804 = pd.DataFrame(logs_ext_2804, columns = ['Epoch','D Loss','G Loss'])

logs_ext_2804['Epoch'] = logs_ext_2804['Epoch'].astype(int)
logs_ext_2804['D Loss'] = logs_ext_2804['D Loss'].astype(float)
logs_ext_2804['G Loss'] = logs_ext_2804['G Loss'].astype(float)

# %%
with open(r"E:\Projects\WGAN-GP_CarBrandSocials\Logs\29_4_25.log", "r") as g:
    lines = g.readlines()

logs_ext_2904 = [re.findall(r"\[Epoch (\d+)/\d+\].*?\[D loss: ([\-\d.]+)\].*?\[G loss: ([\-\d.]+)\]", line)[0]
               for line in lines if "D loss" in line and "G loss" in line]

logs_ext_2904 = pd.DataFrame(logs_ext_2904, columns = ['Epoch','D Loss','G Loss'])

logs_ext_2904['Epoch'] = logs_ext_2904['Epoch'].astype(int)
logs_ext_2904['D Loss'] = logs_ext_2904['D Loss'].astype(float)
logs_ext_2904['G Loss'] = logs_ext_2904['G Loss'].astype(float)

# %%
logs_ext_2804.set_index('Epoch')[['D Loss','G Loss']].plot(figsize = (12,6))
plt.title('Run#1 Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
logs_ext_2904.set_index('Epoch')[['D Loss','G Loss']].plot(figsize = (12,6))
plt.title('Run#1 Losses')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
import torch
import os

torch.save(generator.state_dict(), r"E:\Projects\Data\VW-GAN\Models\generator_epoch500.pth")
torch.save(discriminator.state_dict(), r"E:\Projects\Data\VW-GAN\Models\discriminator_epoch500.pth")
